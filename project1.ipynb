# %%
#1.studen_mark_analyzer

marks = {
    "Aditi": [75, 80, 90],
    "soham": [60, 70, 65],
    "vishvajeet": [90, 95, 88]
}


print("Student-wise Averages:")
for name in marks:
    avg = sum(marks[name]) / 3
    print(f"{name} → Average: {avg:.1f}")


max_total = 0
topper = ""

for name in marks:
    total = sum(marks[name])
    if total > max_total:
        max_total = total
        topper = name

print(f"\nTopper: {topper} with {max_total} marks")

print("\nSubject-wise Averages:")
subjects = ["Math", "Science", "English"]

num_students = len(marks)

for i in range(3): 
    total_sub = 0
    for name in marks:
        total_sub += marks[name][i]
    avg_sub = total_sub / num_students
    print(f"{subjects[i]}: {avg_sub:.1f}")
# Out:
# Student-wise Averages:
# Aditi → Average: 81.7
# soham → Average: 65.0
# vishvajeet → Average: 91.0
#
# Topper: vishvajeet with 273 marks
#
# Subject-wise Averages:
# Math: 75.0
# Science: 81.7
# English: 81.0

# %%
#2. Contact Book Program

contacts = {}   


def add_contact():
    name = input("Enter name: ").strip().lower()
    phone = input("Enter phone: ").strip()
    contacts[name] = phone
    print("Contact added successfully!\n")


def view_contacts():
    if not contacts:
        print("No contacts found.\n")
        return
    print("\n--- All Contacts ---")
    for name, phone in contacts.items():
        print(f"{name.title()} - {phone}")
    print()


def search_contact():
    name = input("Enter name to search: ").strip().lower()
    if name in contacts:
        print(f"Found: {name.title()} - {contacts[name]}\n")
    else:
        print("Contact not found.\n")


def update_contact():
    name = input("Enter name to update: ").strip().lower()
    if name in contacts:
        new_phone = input("Enter new phone number: ").strip()
        contacts[name] = new_phone
        print("Contact updated successfully!\n")
    else:
        print("Contact not found.\n")


def delete_contact():
    name = input("Enter name to delete: ").strip().lower()
    if name in contacts:
        del contacts[name]
        print("Contact deleted successfully!\n")
    else:
        print("Contact not found.\n")


while True:
    print("\n--- Contact Book Menu ---")
    print("1. Add Contact")
    print("2. View Contacts")
    print("3. Search Contact")
    print("4. Update Contact")
    print("5. Delete Contact")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        view_contacts()
    elif choice == "3":
        search_contact()
    elif choice == "4":
        update_contact()
    elif choice == "5":
        delete_contact()
    elif choice == "6":
        print("Exiting Contact Book. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.\n")
# Out:
# --- Contact Book Menu ---
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice:  1
# Enter name:  aditi
# Enter phone:  7382312931283717237
# Contact added successfully!
#
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice:  1
# Enter name:  soham
# Enter phone:  3472741948230
# Contact added successfully!
#
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice:  2
# --- All Contacts ---
# Aditi - 7382312931283717237
# Soham - 3472741948230
#
#
# --- Contact Book Menu ---
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice:  4
# Enter name to update:  aditi
# Enter new phone number:  009238827345423
# Contact updated successfully!
#
#
# ...

# %%
# 3.Simple Banking System

account = {"name": None, "balance": 0}


def create_account():
    name = input("Enter name: ").strip()
    balance = int(input("Enter initial balance: "))
    account["name"] = name
    account["balance"] = balance
    print("Account created successfully!\n")


def check_balance():
    if account["name"] is None:
        print("No account exists. Create an account first.\n")
    else:
        print(f"{account['name']}'s balance: {account['balance']}\n")


def deposit():
    if account["name"] is None:
        print("No account exists. Create an account first.\n")
    else:
        amt = int(input("Enter amount to deposit: "))
        account["balance"] += amt
        print("Deposit successful!\n")


def withdraw():
    if account["name"] is None:
        print("No account exists. Create an account first.\n")
    else:
        amt = int(input("Enter amount to withdraw: "))
        if amt <= account["balance"]:
            account["balance"] -= amt
            print("Withdrawal successful!\n")
        else:
            print("Insufficient balance!\n")



while True:
    print("Welcome to MyBank!")
    print("1. Create Account")
    print("2. Check Balance")
    print("3. Deposit Money")
    print("4. Withdraw Money")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        create_account()
    elif choice == "2":
        check_balance()
    elif choice == "3":
        deposit()
    elif choice == "4":
        withdraw()
    elif choice == "5":
        print("Thank you for using MyBank!")
        break
    else:
        print("Invalid choice. Please enter again.\n")
# Out:
# Welcome to MyBank!
# 1. Create Account
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  1
# Enter name:  am
# Enter initial balance:  237127
# Account created successfully!
#
# Welcome to MyBank!
# 1. Create Account
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  2
# am's balance: 237127
#
# Welcome to MyBank!
# 1. Create Account
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  3
# Enter amount to deposit:  486
# Deposit successful!
#
# Welcome to MyBank!
# 1. Create Account
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  2
# am's balance: 237613
#
# Welcome to MyBank!
# 1. Create Account
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  5
# Thank you for using MyBank!

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Aditi\Downloads\50_students_marks.csv")  

print("Student Marks:\n", df.head())


df['Average'] = df[['Subject1', 'Subject2', 'Subject3']].mean(axis=1)

print("\nStudent-wise Averages:")
for index, row in df.iterrows():
    print(f"{row['Name']} → Average: {row['Average']:.1f}")


topper = df.loc[df['Average'].idxmax()]
print(f"\nTopper: {topper['Name']} with Average: {topper['Average']:.1f}")
# Out:
# Student Marks:
#         Name  Subject1  Subject2  Subject3
# 0  Student1        81        96        92
# 1  Student2        75        90        58
# 2  Student3        76        46       100
# 3  Student4        40        96        93
# 4  Student5        56        64        35
#
# Student-wise Averages:
# Student1 → Average: 89.7
# Student2 → Average: 74.3
# Student3 → Average: 74.0
# Student4 → Average: 76.3
# Student5 → Average: 51.7
# Student6 → Average: 56.7
# Student7 → Average: 66.3
# Student8 → Average: 57.3
# Student9 → Average: 66.3
# Student10 → Average: 65.7
# Student11 → Average: 76.7
# Student12 → Average: 80.0
# Student13 → Average: 93.0
# Student14 → Average: 79.0
# Student15 → Average: 72.7
# Student16 → Average: 54.3
# Student17 → Average: 68.3
# Student18 → Average: 71.3
# Student19 → Average: 73.3
# Student20 → Average: 71.3
# Student21 → Average: 74.0
# Student22 → Average: 63.0
# Student23 → Average: 73.7
# Student24 → Average: 64.0
# Student25 → Average: 57.7
# ...
